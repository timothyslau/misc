# %%
# !pip install tabula-py
# !pip install PyPDF2
# !wget https://www.nichd.nih.gov/sites/default/files/inline-files/FGCalculatorPercentileRange.pdf # linux
# !curl -o /Users/laut/Downloads/FGCalculatorPercentileRange.pdf https://www.nichd.nih.gov/sites/default/files/inline-files/FGCalculatorPercentileRange.pdf # osx
# Out:
# Requirement already satisfied: tabula-py in /Users/laut/miniconda3/envs/conda_dev/lib/python3.11/site-packages (2.9.0)
# Requirement already satisfied: pandas>=0.25.3 in /Users/laut/miniconda3/envs/conda_dev/lib/python3.11/site-packages (from tabula-py) (1.5.3)
# Requirement already satisfied: numpy in /Users/laut/miniconda3/envs/conda_dev/lib/python3.11/site-packages (from tabula-py) (1.24.2)
# Requirement already satisfied: distro in /Users/laut/miniconda3/envs/conda_dev/lib/python3.11/site-packages (from tabula-py) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/laut/miniconda3/envs/conda_dev/lib/python3.11/site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/laut/miniconda3/envs/conda_dev/lib/python3.11/site-packages (from pandas>=0.25.3->tabula-py) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/laut/miniconda3/envs/conda_dev/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->tabula-py) (1.16.0)
# Requirement already satisfied: PyPDF2 in /Users/laut/miniconda3/envs/conda_dev/lib/python3.11/site-packages (3.0.1)

# %%
import pandas as pd
import tabula as tp
import PyPDF2 as ppdf

# %%
def foo(path):
    df_list = []
    for i in range(1,len(ppdf.PdfReader(stream=path).pages) + 1):
        df0 = tp.read_pdf(input_path=path, pages=i)[0]
        df_list.append(df0)
    df1 = pd.concat(df_list)
    df1.columns = [x.replace("\r", "_").replace(" ", "_").lower() for x in df1.columns]
    return df1

df1 = foo(path='/Users/laut/Downloads/FGCalculatorPercentileRange.pdf')

# %%
df1
# Out:
#     gestational_age_(weeks)                      race         measure  \
# 0                     10.00        Non-Hispanic White  Abdominal Circ
# 1                     10.14        Non-Hispanic White  Abdominal Circ
# 2                     10.29        Non-Hispanic White  Abdominal Circ
# 3                     10.43        Non-Hispanic White  Abdominal Circ
# 4                     10.57        Non-Hispanic White  Abdominal Circ
# ..                      ...                       ...             ...
# 23                    41.43  Asian & Pacific Islander      Head Circ.
# 24                    41.57  Asian & Pacific Islander      Head Circ.
# 25                    41.71  Asian & Pacific Islander      Head Circ.
# 26                    41.86  Asian & Pacific Islander      Head Circ.
# 27                    42.00  Asian & Pacific Islander      Head Circ.
#
#     3rd_percentile  5th_percentile  10th_percentile  50th_percentile  \
# 0            30.46           31.09            32.08            35.83
# 1            31.59           32.24            33.26            37.13
# 2            32.74           33.41            34.46            38.44
# 3            33.91           34.60            35.68            39.78
# 4            35.10           35.81            36.92            41.14
# ..             ...             ...              ...              ...
# 23          307.73          310.86           315.75           333.62
# 24          307.49          310.65           315.58           333.60
# 25          307.22          310.41           315.38           333.56
# 26          306.91          310.13           315.14           333.49
# 27          306.56          309.81           314.87           333.41
#
#     90th_percentile  95th_percentile  97th_percentile
# 0             40.03            41.30            42.15
# 1             41.44            42.76            43.63
# 2             42.89            44.24            45.14
# 3             44.35            45.74            46.67
# 4             45.85            47.27            48.23
# ..              ...              ...              ...
# 23           352.50           358.05           361.69
# 24           352.65           358.25           361.93
# 25           352.79           358.44           362.16
# 26           352.92           358.62           362.38
# 27           353.03           358.81           362.60
#
# [3600 rows x 10 columns]

# %%
df1.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3600 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gestational_age_(weeks)  3600 non-null   float64
#  1   race                     3600 non-null   object
#  2   measure                  3600 non-null   object
#  3   3rd_percentile           3600 non-null   float64
#  4   5th_percentile           3600 non-null   float64
#  5   10th_percentile          3600 non-null   float64
#  6   50th_percentile          3600 non-null   float64
#  7   90th_percentile          3600 non-null   float64
#  8   95th_percentile          3600 non-null   float64
#  9   97th_percentile          3600 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 309.4+ KB

# %%
df1.to_csv(path_or_buf="/Users/laut/Downloads/fetalgrowthcalculatorpercentilerange.tsv", sep="\t", index=False)
